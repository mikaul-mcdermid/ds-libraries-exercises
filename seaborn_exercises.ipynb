# %% [markdown]
# Exercises
#
# Create a file named seaborn_exercises.py or seaborn_exercises.ipynb for this exercise.
#
# Use seaborn's load_dataset function to load the iris database to answer the following questions:
#
# What does the distribution of petal lengths look like?
# Is there a relationship between petal length and petal width?
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.
# Which features would be best used to predict species?
# Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
#
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.
# Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.
#
# Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:
#
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
# Does whether or not a province is Catholic influence fertility?
# What measure correlates most strongly with fertility?
# Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.
#
# Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
iris = sns.load_dataset('iris')
sns.load_dataset('iris')
# Continuous = everything minus species
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# What does the distribution of petal lengths look like?
sns.histplot(data=iris, x="petal_length", kde=True)
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.title("Distribution of Petal Lengths in Iris Dataset")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Relationship Between Petal Length and Petal Width")
plt.show()

# %%
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

sns.scatterplot(data=iris, x="sepal_length", y="sepal_width", hue="species", palette="Set1")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Sepal Length vs Sepal Width by Species")
plt.legend(title="Species")
plt.show()

# %%
sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
plt.show()
corner = True
correlation_matrix = iris.corr()
correlation_with_species = correlation_matrix["species"].abs().sort_values(ascending=False)
print(correlation_with_species)
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 4
#       2 plt.show()
#       3 corner = True
# ----> 4 correlation_matrix = iris.corr()
#       5 correlation_with_species = correlation_matrix["species"].abs().sort_values(ascending=False)
#       6 print(correlation_with_species)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
# Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

import seaborn as sns
import pandas as pd

# Load the Anscombe dataset
anscombe = sns.load_dataset("anscombe")

# Group the data by the "dataset" column
grouped_data = anscombe.groupby("dataset")

# Calculate summary statistics for each dataset
summary_statistics = grouped_data.describe()

# Print the summary statistics
print(summary_statistics)
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
anscombe.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
sns.relplot(data=anscombe, x='x', y='y', col='dataset')
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# To plot the x and y values from the Anscombe dataset with each dataset in a separate column, you can create a pairplot using Seaborn. Here's how you can do it:
# Load the Anscombe dataset
anscombe = sns.load_dataset("anscombe")

# Create a pairplot with each dataset in a separate column
sns.pairplot(data=anscombe, hue="dataset", markers=["o", "s", "D", "P"])
plt.show()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.
from pydataset import data
# Load the InsectSprays dataset
insect_sprays = data("InsectSprays")
insect_sprays.describe()
# Out:
#            count
# count  72.000000
# mean    9.500000
# std     7.203286
# min     0.000000
# 25%     3.000000
# 50%     7.000000
# 75%    14.250000
# max    26.000000

# %%
sns.boxplot(data=insect_sprays, x='spray', y='count')
# Out:
# <Axes: xlabel='spray', ylabel='count'>

# %%
# Create a boxplot to show the effectiveness of different insect sprays
plt.figure(figsize=(10, 6))
sns.boxplot(data=insect_sprays, x='spray', y='count')
plt.xlabel("Insect Spray")
plt.ylabel("Effectiveness")
plt.title("Effectiveness of Different Insect Sprays")
plt.show()

# %%
swiss = data("swiss")

# %%
# threshold = 50 this is a variable method, just using a number works
swiss['is_catholic'] = swiss['Catholic'] > 50
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
# Choose a threshold (e.g., 60%) to define what constitutes a Catholic province
threshold = 60

# Create the is_catholic attribute as a boolean column
swiss['is_catholic'] = swiss['Catholic'] > threshold

# Visualize the dataset with the is_catholic attribute
print(swiss.head())
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
# Does whether or not a province is Catholic influence fertility?
# Calculate the correlation coefficient between Catholic and Fertility
correlation = swiss['Catholic'].corr(swiss['Fertility'])
print(f"Correlation between Catholic and Fertility: {correlation:.2f}")
# Out:
# Correlation between Catholic and Fertility: 0.46

# %%
sns.boxplot(data=swiss, x='is_catholic', y='Fertility')
# Out:
# <Axes: xlabel='is_catholic', ylabel='Fertility'>

# %%
swiss.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.402813     0.410503    -0.597861  -0.154677  0.961723
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.402813
# Agriculture              -0.060859     0.410503
# Examination              -0.114022    -0.597861
# Education                -0.099322    -0.154677
# Catholic                  0.175496     0.961723
# Infant.Mortality          1.000000     0.166081
# ...

# %%
sns.heatmap(swiss.corr()[:1], cmap='Greens', annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=swiss, x='Catholic', y='Fertility')
plt.xlabel("Percentage of Catholics")
plt.ylabel("Fertility Rate")
plt.title("Relationship between Catholic Population and Fertility")
plt.show()

# %%
# Calculate the correlation coefficients between Fertility and other measures
correlation_with_fertility = swiss.corr()['Fertility'].drop('Fertility')

# Find the measure that correlates most strongly with Fertility
strongest_correlation_measure = correlation_with_fertility.idxmax()
strongest_correlation_coefficient = correlation_with_fertility.max()

print(f"The measure that correlates most strongly with Fertility is '{strongest_correlation_measure}' with a correlation coefficient of {strongest_correlation_coefficient:.2f}")
# Out:
# The measure that correlates most strongly with Fertility is 'is_catholic' with a correlation coefficient of 0.61

# %%
# Assuming you have the Chipotle dataset loaded into a DataFrame named 'chipotle_data'
import env

# # Group the data by item name, calculate the total revenue for each item, and sort by revenue in descending order
# item_revenue = chipotle_data.groupby('item_name')['item_price'].sum().sort_values(ascending=False)

# # Get the top 4 most popular items and their corresponding revenues
# top_4_items = item_revenue.head(4)

# # Create a bar chart
# plt.figure(figsize=(10, 6))
# top_4_items.plot(kind='bar', color='skyblue')
# plt.title('Four Most Popular Items and Their Revenue')
# plt.xlabel('Item Name')
# plt.ylabel('Total Revenue')
# plt.xticks(rotation=45)
# plt.show()

# %%
get_db_url(env.username,env.password,env.hostname, 'chipotle')
url = get
# Out:
# 'mysql+pymysql://ursula_2331:NEaRs4EW1KflzlBriavfHaieCVeMTADH@data.codeup.com/employees'

# %%
total_revenue = chipot

# %%
query = 'SELECT * FROM orders'

chipotle = pd.read_sql(query, url)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ...

# %%
sns.dogplot()

# %%
import env

# %%
def get_db_url(username, password, hostname, database_name):
    return f'mysql+pymysql://{env.username}:{env.password}@{env.hostname}/{database_name}'
url = get_db_url(env.username,env.password,env.hostname, 'chipotle')

# %%
url
# Out:
# 'mysql+pymysql://ursula_2331:NEaRs4EW1KflzlBriavfHaieCVeMTADH@data.codeup.com/chipotle'

# %%
# Out:
# <module 'env' from '/Users/mikaulmcdermid/codeup-data-science/Codeup-data-science/ds-libraries-exercises/env.py'>

# %%
import Mikaul as mf
url = mf.get_db_url('database')

# %%
sns.displot(data=iris, x='petal_length')
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df=data('sleepstudy')
df.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data=df, x='Days', y='Reaction', hue='Subject', alpha=0.4)
sns.lineplot(data=df, x='Days', y='Reaction', c='black', linewidth=6)
plt.show()

# %%
df.dtypes
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
df.Subject.nunique()
# Out:
# 18

# %%
df.Subject = df.Subject.astype(str)
